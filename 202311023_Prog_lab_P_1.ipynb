# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 91  49.99  50.02  50.00  50.01  49.86  49.94  50.01  49.98  49.97  49.96
# 92  50.00  50.03  50.06  50.01  49.91  49.86  50.01  49.98  49.94  49.90
# 93  49.96  50.01  50.04  49.97  49.97  49.83  50.01  49.91  49.98  49.92
# 94  50.02  49.99  50.04  50.01  49.99  49.86  50.00  49.94  49.92  50.00
# 95  49.99  49.99  50.04  50.06  50.02  49.94  50.01  49.97  49.99  49.99
#
# [96 rows x 32 columns]

# %%
months=['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov',]
df={}
for i in months:
  df[i] = pd.read_csv(f'/content/{i}.csv')
  df[i] = df[i].iloc[:,1:]

df['dec'] = pd.read_csv('/content/dec.csv')

# %%
def date_col(df,master_df):
  x=df.shape[1]
  new=[]
  for i in range(1,x):
    for j in range(96):
      new.append(i)

  master_df['date'] = new

# %%
def fill(df,master_df,m):
  def day_or_night(hour):
    if 6 <= hour <= 18:
        return 'day'
    else:
        return 'night'

  master_df[['Hour', 'Minute']] = df['Time'].str.split(':', expand=True)

  # Convert 'Hour' and 'Minute' columns to integers
  master_df['Hour'] = master_df['Hour'].astype(int)
  master_df['Minute'] = master_df['Minute'].astype(int)

  # Apply the function to create a new 'Day_Night' column
  master_df['time_of_day'] = master_df['Hour'].apply(day_or_night)
  master_df['year'] = master_df['year'].fillna(2022)
  master_df['month'] = master_df['month'].fillna(m)

# %%
def master(df,m):
  new_df = df.drop('Time',axis=1)
  master_df = pd.DataFrame(columns=['frequency','date','month','year','Hour','Minute','time_of_day'])
  master_df['frequency'] = pd.concat([new_df[col] for col in new_df.columns], axis=0)
  date_col(df,master_df)
  fill(df,master_df,m)
  return master_df

# %%
master(some,3)
# Out:
#     frequency  date  month  year  Hour  Minute time_of_day
# 0       49.96     1      3  2022     0       0       night
# 1       49.99     1      3  2022     0      15       night
# 2       49.99     1      3  2022     0      30       night
# 3       49.98     1      3  2022     0      45       night
# 4       49.99     1      3  2022     1       0       night
# ..        ...   ...    ...   ...   ...     ...         ...
# 91      49.98    31      3  2022    22      45       night
# 92      49.90    31      3  2022    23       0       night
# 93      49.91    31      3  2022    23      15       night
# 94      49.94    31      3  2022    23      30       night
# 95      49.99    31      3  2022    23      45       night
#
# [2976 rows x 7 columns]

# %%
# this function helps converting the data from df to master_df
val=1
for i in months:
  df[i] = master(df[i],val)
  val +=1


# master_df

# %%
df['dec'] = master(df['dec'],12)

# %%
df['dec']
# Out:
#     frequency  date  month  year  Hour  Minute time_of_day
# 0       50.05     1     12  2022     0       0       night
# 1       50.00     1     12  2022     0      15       night
# 2       50.00     1     12  2022     0      30       night
# 3       49.97     1     12  2022     0      45       night
# 4       49.98     1     12  2022     1       0       night
# ..        ...   ...    ...   ...   ...     ...         ...
# 91      49.96    31     12  2022    22      45       night
# 92      49.90    31     12  2022    23       0       night
# 93      49.92    31     12  2022    23      15       night
# 94      50.00    31     12  2022    23      30       night
# 95      49.99    31     12  2022    23      45       night
#
# [2976 rows x 7 columns]

# %%
super_df = pd.concat(df.values(), ignore_index=True)
super_df
# Out:
#        frequency  date  month  year  Hour  Minute time_of_day
# 0          50.03     1      1  2022     0       0       night
# 1          50.01     1      1  2022     0      15       night
# 2          50.01     1      1  2022     0      30       night
# 3          50.02     1      1  2022     0      45       night
# 4          50.02     1      1  2022     1       0       night
# ...          ...   ...    ...   ...   ...     ...         ...
# 34939      49.96    31     12  2022    22      45       night
# 34940      49.90    31     12  2022    23       0       night
# 34941      49.92    31     12  2022    23      15       night
# 34942      50.00    31     12  2022    23      30       night
# 34943      49.99    31     12  2022    23      45       night
#
# [34944 rows x 7 columns]

# %%
super_df.to_csv('dsg2022.csv')
